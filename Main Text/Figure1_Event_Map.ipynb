# %%
import pygmt
from salvus import namespace as sn
import numpy as np


sp = sn.Project(path="CANV_FULL")
wus = sn.Project(path="CANV256")
cs = sn.Project(path="CANV_CSEM")
# Out:
# --> Server: 'https://l.mondaic.com/licensing_server', User: 'claire.doody', Group: 'LLNL'.
# --> Negotiating 1 license instance(s) for 'SalvusMesh' [license version 1.0.0] for 1 seconds ...
# --> Success! [Total duration: 1.29 seconds]
# Accordion(children=(HTML(value='\n                <head>\n                <style>\n                td {\n     …
# Accordion(children=(HTML(value='\n                <head>\n                <style>\n                td {\n     …
# Accordion(children=(HTML(value='\n                <head>\n                <style>\n                td {\n     …

# %%
grid = pygmt.datasets.load_earth_relief(resolution="01m", region = [-127,-112,30,44.5] )
# Out:
# grdblend [NOTICE]: Remote data courtesy of GMT data server oceania [http://oceania.generic-mapping-tools.org]
# grdblend [NOTICE]: SRTM15 Earth Relief at 01x01 arc minutes reduced by Gaussian Cartesian filtering (1.9 km fullwidth) [Tozer et al., 2019].
# grdblend [NOTICE]:   -> Download 30x30 degree grid tile (earth_relief_01m_p): N30W150

# %%
unique_stas = []
sta_lats = []
sta_lons = []
nets = []

for event_name in sp.events.list():
    event = sp.events.get(event_name=event_name)
    for  idx in np.arange(0, len(event.receiver_name_list), 1):   
        sta = event.receivers[idx].to_json()
        args = sta['arguments']
        sncl = str(str(args['network_code'])+'.'+str(args['station_code'])+'.')
        
        if sncl not in unique_stas:
            unique_stas.append(sncl)
            
            sta_lat = (sn.simple_config.coordinate_system_utils._geocentric_to_elliptic_latitude(lat=args['latitude']))
            sta_lon = args['longitude'] 
            netcode = str(args['network_code'])
            
            sta_lats.append(sta_lat)
            sta_lons.append(sta_lon)

# %%
fig = pygmt.Figure()

#fig.grdimage(grid=grid, projection='L-119.5/37.25/30/44.5/15c', cmap="gray")
fig.coast(shorelines = '1/0.5p', region = [-127,-112,30,44.5], projection='L-119.5/37.25/30/44.5/15c',
            frame = 'af', borders=["1/thick,black", "2/thick,black"])
#fig.colorbar(frame=["a1000", "x+lElevation", "y+lm"])

fig.plot(region = [-127,-112,30,44.5], projection='L-119.5/37.25/30/44.5/15c',
        frame = None, x = [-125,-114], y = [31.5,31.5], pen="3p,black")
fig.plot(region = [-127,-112,30,44.5], projection='L-119.5/37.25/30/44.5/15c',
        frame = None, x =[-125,-114] , y = [43,43], pen="3p,black")

fig.plot(region = [-127,-112,30,44.5], projection='L-119.5/37.25/30/44.5/15c',
        frame = None, x = [-125,-125], y = [31.5,43], pen="3p,black")
fig.plot(region = [-127,-112,30,44.5], projection='L-119.5/37.25/30/44.5/15c',
        frame = None, x = [-114,-114], y = [31.5,43], pen="3p,black")


fig.plot(x = sta_lons, y = sta_lats, style="i0.3c",color = 'black')
            
            
for eve in sp.events.list():
    print('SPiRaL' + eve)
    syn1 = sp.waveforms.get(data_name='initial_model_20_80_seconds', events=eve)
    event = sp.events.get(event_name=eve)
    eve_meta = event.sources[0]._initial_arguments
    dsc = sp.entities.get(
    entity_type="data_selection_configuration",
    entity_name="dsc_20_80_seconds")

    dsc = dsc.get_event_window_and_weight_set(sp.events.get(event_name=event_name))
    windowed_stas = []
    for idx in dsc.receivers:
        vals = dsc.receivers[idx]
        if len(vals['components']['Z']['windows'])>=1:
            windowed_stas.append(idx)
        elif len(vals['components']['N']['windows'])>=1:
            if idx in windowed_stas:
                pass
            else:
                windowed_stas.append(idx)
        elif len(vals['components']['E']['windows'])>=1:
            if idx in windowed_stas:
                pass
            else:
                windowed_stas.append(idx)
            
    for  idx in np.arange(0, len(syn1[0].receiver_name_list), 1):   
        sta = syn1[0].receivers[idx].to_json()
        args = sta['arguments']
        sta_lat  =  (
        # This function defaults to the WGS84 ellipsoid but others are possible.
        sn.simple_config.coordinate_system_utils._geocentric_to_elliptic_latitude(
            lat=args['latitude']))
        sta_lon = args['longitude']

        sncl = str(args['network_code']+'.'+ args['station_code']+'.')
        if sncl in windowed_stas:
            fig.plot(x=[eve_meta['longitude'], sta_lon], y=[eve_meta['latitude'], sta_lat], 
                         color = 'red', transparency=95)
for eve in wus.events.list():
    print('WUS' + eve)
    syn1 = wus.waveforms.get(data_name='initial_model_wus_20-80_seconds', events=eve)
    event = wus.events.get(event_name=eve)
    eve_meta = event.sources[0]._initial_arguments
    dsc = wus.entities.get(
    entity_type="data_selection_configuration",
    entity_name="wus_20-80_seconds")

    dsc = dsc.get_event_window_and_weight_set(wus.events.get(event_name=event_name))
    windowed_stas = []
    for idx in dsc.receivers:
        vals = dsc.receivers[idx]
        if len(vals['components']['Z']['windows'])>=1:
            windowed_stas.append(idx)
        elif len(vals['components']['N']['windows'])>=1:
            if idx in windowed_stas:
                pass
            else:
                windowed_stas.append(idx)
        elif len(vals['components']['E']['windows'])>=1:
            if idx in windowed_stas:
                pass
            else:
                windowed_stas.append(idx)
    for  idx in np.arange(0, len(syn1[0].receiver_name_list), 1):   
        sta = syn1[0].receivers[idx].to_json()
        args = sta['arguments']
        sta_lat  =  (
        # This function defaults to the WGS84 ellipsoid but others are possible.
        sn.simple_config.coordinate_system_utils._geocentric_to_elliptic_latitude(
            lat=args['latitude']))
        sta_lon = args['longitude']

        sncl = str(args['network_code']+'.'+ args['station_code']+'.')
        if sncl in windowed_stas:
            fig.plot(x = [eve_meta['longitude'], sta_lon], y = [eve_meta['latitude'], sta_lat], 
                         color = 'red', transparency=95)
            
for eve in cs.events.list():
    print('CSEM' + eve)
    syn1 = cs.waveforms.get(data_name='initial_model_20-80_seconds', events=eve)
    event = cs.events.get(event_name=eve)
    eve_meta = event.sources[0]._initial_arguments
    dsc = cs.entities.get(
    entity_type="data_selection_configuration",
    entity_name="dsc_20-80_seconds")

    dsc = dsc.get_event_window_and_weight_set(cs.events.get(event_name=event_name))
    windowed_stas = []
    for idx in dsc.receivers:
        vals = dsc.receivers[idx]
        if len(vals['components']['Z']['windows'])>=1:
            windowed_stas.append(idx)
        elif len(vals['components']['N']['windows'])>=1:
            if idx in windowed_stas:
                pass
            else:
                windowed_stas.append(idx)
        elif len(vals['components']['E']['windows'])>=1:
            if idx in windowed_stas:
                pass
            else:
                windowed_stas.append(idx)
    for  idx in np.arange(0, len(syn1[0].receiver_name_list), 1):   
        sta = syn1[0].receivers[idx].to_json()
        args = sta['arguments']
        sta_lat  =  (
        # This function defaults to the WGS84 ellipsoid but others are possible.
        sn.simple_config.coordinate_system_utils._geocentric_to_elliptic_latitude(
            lat=args['latitude'])) 
        sta_lon = args['longitude']

        sncl = str(args['network_code']+'.'+ args['station_code']+'.')
        if sncl in windowed_stas:
            fig.plot(x = [eve_meta['longitude'], sta_lon], y = [eve_meta['latitude'], sta_lat], 
                         color = 'red', transparency=95)
            
for eve in sp.events.list():
    event = sp.events.get(event_name=eve)
    eve_meta = event.sources[0]._initial_arguments
    mt = {'mrr': eve_meta['mrr'], 'mtt': eve_meta['mtt'],'mff':eve_meta['mpp'],
              'mrt': eve_meta['mrt'], 'mrf': eve_meta['mrp'], 'mtf':eve_meta['mtp'], 'exponent':16}
    fig.meca(mt, scale="0.3c", longitude=eve_meta['longitude'], 
             latitude=eve_meta['latitude'], depth=eve_meta['depth_in_m']/1000.)

fig.show()
# Out:
# SPiRaLevent_BAJA_CALIFORNIA_MEXICO_Mag_4.85_2010-04-15-10-20
# SPiRaLevent_BAJA_CALIFORNIA_MEXICO_Mag_4.86_2010-09-20-00-30
# SPiRaLevent_BAJA_CALIFORNIA_MEXICO_Mag_5.02_2015-02-09-01-45
# SPiRaLevent_BAJA_CALIFORNIA_MEXICO_Mag_5.03_2010-09-14-10-52
# SPiRaLevent_BAJA_CALIFORNIA_MEXICO_Mag_5.15_2011-02-18-17-47
# SPiRaLevent_CALIF.-BAJA_CALIF._BORDER_REGION_Mag_4.82_2012-07-01-03-25
# SPiRaLevent_CALIF.-BAJA_CALIF._BORDER_REGION_Mag_4.84_2008-02-20-01-28
# SPiRaLevent_CALIF.-BAJA_CALIF._BORDER_REGION_Mag_4.84_2010-12-11-12-52
# SPiRaLevent_CALIF.-BAJA_CALIF._BORDER_REGION_Mag_4.85_2012-07-01-06-36
# SPiRaLevent_CALIF.-BAJA_CALIF._BORDER_REGION_Mag_4.86_2010-05-08-18-46
# SPiRaLevent_CALIF.-BAJA_CALIF._BORDER_REGION_Mag_4.91_2008-02-22-19-31
# SPiRaLevent_CALIF.-BAJA_CALIF._BORDER_REGION_Mag_4.97_2010-05-08-18-33
# SPiRaLevent_CALIF.-BAJA_CALIF._BORDER_REGION_Mag_4.98_2010-04-05-13-33
# SPiRaLevent_CALIF.-BAJA_CALIF._BORDER_REGION_Mag_5.01_2020-10-01-00-31
# SPiRaLevent_CALIF.-BAJA_CALIF._BORDER_REGION_Mag_5.03_2008-02-12-04-32
# SPiRaLevent_CALIF.-BAJA_CALIF._BORDER_REGION_Mag_5.04_2004-06-15-22-28
# SPiRaLevent_CALIF.-BAJA_CALIF._BORDER_REGION_Mag_5.06_2010-05-22-17-31
# SPiRaLevent_CALIF.-BAJA_CALIF._BORDER_REGION_Mag_5.11_2008-02-19-22-41
# SPiRaLevent_CALIF.-BAJA_CALIF._BORDER_REGION_Mag_5.14_2008-02-11-18-29
# SPiRaLevent_CALIF.-BAJA_CALIF._BORDER_REGION_Mag_5.16_2008-02-09-07-12
# SPiRaLevent_CALIF.-BAJA_CALIF._BORDER_REGION_Mag_5.17_2009-09-19-22-55
# SPiRaLevent_CALIF.-BAJA_CALIF._BORDER_REGION_Mag_5.29_2006-05-24-04-20
# SPiRaLevent_CALIF.-BAJA_CALIF._BORDER_REGION_Mag_5.37_2010-04-08-16-44
# SPiRaLevent_CALIF.-BAJA_CALIF._BORDER_REGION_Mag_5.41_2012-08-26-19-31
# SPiRaLevent_CALIF.-BAJA_CALIF._BORDER_REGION_Mag_5.47_2002-02-22-19-32
# SPiRaLevent_CALIF.-BAJA_CALIF._BORDER_REGION_Mag_5.49_2012-08-26-20-58
# SPiRaLevent_CALIF.-BAJA_CALIF._BORDER_REGION_Mag_5.81_2010-06-15-04-27
# SPiRaLevent_CALIF.-BAJA_CALIF._BORDER_REGION_Mag_5.87_2009-12-30-18-49
# SPiRaLevent_CALIFORNIA-NEVADA_BORDER_REGION_Mag_4.67_2020-04-11-16-22
# SPiRaLevent_CALIFORNIA-NEVADA_BORDER_REGION_Mag_4.83_2020-08-19-17-32
# SPiRaLevent_CALIFORNIA-NEVADA_BORDER_REGION_Mag_4.88_2009-10-03-01-09
# SPiRaLevent_CALIFORNIA-NEVADA_BORDER_REGION_Mag_4.91_2016-02-16-23-04
# SPiRaLevent_CALIFORNIA-NEVADA_BORDER_REGION_Mag_4.93_2015-02-14-02-29
# SPiRaLevent_CALIFORNIA-NEVADA_BORDER_REGION_Mag_5.14_2009-10-01-10-01
# SPiRaLevent_CALIFORNIA-NEVADA_BORDER_REGION_Mag_5.23_2009-10-03-01-16
# SPiRaLevent_CALIFORNIA-NEVADA_BORDER_REGION_Mag_5.26_2013-02-13-00-10
# SPiRaLevent_CALIFORNIA-NEVADA_BORDER_REGION_Mag_5.26_2020-04-11-14-36
# SPiRaLevent_CALIFORNIA-NEVADA_BORDER_REGION_Mag_5.37_2004-09-18-23-43
# SPiRaLevent_CALIFORNIA-NEVADA_BORDER_REGION_Mag_5.39_2004-09-18-23-02
# SPiRaLevent_CALIFORNIA-NEVADA_BORDER_REGION_Mag_5.59_2016-12-28-08-22
# SPiRaLevent_CALIFORNIA-NEVADA_BORDER_REGION_Mag_5.69_2016-12-28-08-18
# SPiRaLevent_CALIFORNIA-NEVADA_BORDER_REGION_Mag_5.72_2016-12-28-09-13
# SPiRaLevent_CALIFORNIA-NEVADA_BORDER_REGION_Mag_5.84_2020-06-24-17-40
# SPiRaLevent_CENTRAL_CALIFORNIA_Mag_4.64_2019-10-15-05-33
# SPiRaLevent_CENTRAL_CALIFORNIA_Mag_4.69_2017-11-13-19-31
# SPiRaLevent_CENTRAL_CALIFORNIA_Mag_4.82_2011-08-27-07-18
# SPiRaLevent_CENTRAL_CALIFORNIA_Mag_4.85_2019-10-15-19-42
# SPiRaLevent_CENTRAL_CALIFORNIA_Mag_4.94_2004-09-30-18-54
# SPiRaLevent_CENTRAL_CALIFORNIA_Mag_4.95_2016-02-24-00-02
# SPiRaLevent_CENTRAL_CALIFORNIA_Mag_5.02_2004-09-29-22-54
# SPiRaLevent_CENTRAL_CALIFORNIA_Mag_5.06_2019-08-22-20-49
# SPiRaLevent_CENTRAL_CALIFORNIA_Mag_5.07_2004-09-29-17-10
# SPiRaLevent_CENTRAL_CALIFORNIA_Mag_5.38_2012-10-21-06-55
# SPiRaLevent_CENTRAL_CALIFORNIA_Mag_5