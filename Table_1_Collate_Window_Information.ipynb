# %%
#import cartopy
#import cartopy.mpl.geoaxes
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

import numpy as np
import obspy as op
import pandas as pd
from salvus import namespace as sn
#import cartopy.crs as ccrs
#import cartopy.feature as cfeature
from obspy.imaging.beachball import beach
from obspy.geodetics.base import gps2dist_azimuth

sp = sn.Project(path="CANV_FULL")
wus = sn.Project(path='CANV256')
csem = sn.Project(path = 'CSEM_RETEST')
# Out:
# --> Server: 'https://l.mondaic.com/licensing_server', User: 'claire.doody', Group: 'LLNL'.
# --> Negotiating 1 license instance(s) for 'SalvusMesh' [license version 1.0.0] for 1 seconds ...
# --> Success! [Total duration: 0.79 seconds]
# Accordion(children=(HTML(value='\n                <head>\n                <style>\n                td {\n     …
# Accordion(children=(HTML(value='\n                <head>\n                <style>\n                td {\n     …
# Accordion(children=(HTML(value='\n                <head>\n                <style>\n                td {\n     …

# %%
lat_min = 31.5
lat_max = 43
lon_min = -125.0
lon_max = -114.0

#event_name = 'event_CALIFORNIA-NEVADA_BORDER_REGION_Mag_5.84_2020-06-24-17-40'

# %%
step = []

for eve in wus.events.list():
    ds_wus = wus.entities.get(
            entity_type="data_selection_configuration",
            entity_name="WUS256",
            )
    ds_wus = ds_wus.get_event_window_and_weight_set(wus.events.get(event_name=eve))
    for idx in ds_wus.receivers:
        step.append(eve+'/'+idx)

# %%
z_windows_wus = []
n_windows_wus = []
e_windows_wus = []

z1_win_start_wus = []
n1_win_start_wus = []
e1_win_start_wus = []
z1_win_end_wus = []
n1_win_end_wus = []
e1_win_end_wus = []


z2_win_start_wus = []
n2_win_start_wus = []
e2_win_start_wus = []
z2_win_end_wus = []
n2_win_end_wus = []
e2_win_end_wus = []


z3_win_start_wus = []
n3_win_start_wus = []
e3_win_start_wus = []
z3_win_end_wus = []
n3_win_end_wus = []
e3_win_end_wus = []


z4_win_start_wus = []
n4_win_start_wus = []
e4_win_start_wus = []
z4_win_end_wus = []
n4_win_end_wus = []
e4_win_end_wus = []


z5_win_start_wus = []
n5_win_start_wus = []
e5_win_start_wus = []
z5_win_end_wus = []
n5_win_end_wus = []
e5_win_end_wus = []

for eve in wus.events.list():
    ds_wus = wus.entities.get(
            entity_type="data_selection_configuration",
            entity_name="WUS256",
            )
    ds_wus = ds_wus.get_event_window_and_weight_set(wus.events.get(event_name=eve))
    for idx in ds_wus.receivers:
        vals = ds_wus.receivers[idx]
        for comp in ['Z','N','E']:
            if len(vals['components'][comp]['windows'])==0:
                if comp == 'Z':
                    z_windows_wus.append(0)
                    z1_win_start_wus.append(0)
                    z1_win_end_wus.append(0)
                    z2_win_start_wus.append(0)
                    z2_win_end_wus.append(0)
                    z3_win_start_wus.append(0)
                    z3_win_end_wus.append(0)
                    z4_win_start_wus.append(0)
                    z4_win_end_wus.append(0)
                    z5_win_start_wus.append(0)
                    z5_win_end_wus.append(0)
                elif comp == 'N':
                    n_windows_wus.append(0)
                    n1_win_start_wus.append(0)
                    n1_win_end_wus.append(0)
                    n2_win_start_wus.append(0)
                    n2_win_end_wus.append(0)
                    n3_win_start_wus.append(0)
                    n3_win_end_wus.append(0)
                    n4_win_start_wus.append(0)
                    n4_win_end_wus.append(0)
                    n5_win_start_wus.append(0)
                    n5_win_end_wus.append(0)
                elif comp =='E':
                    e_windows_wus.append(0)
                    e1_win_start_wus.append(0)
                    e1_win_end_wus.append(0)
                    e2_win_start_wus.append(0)
                    e2_win_end_wus.append(0)
                    e3_win_start_wus.append(0)
                    e3_win_end_wus.append(0)
                    e4_win_start_wus.append(0)
                    e4_win_end_wus.append(0)
                    e5_win_start_wus.append(0)
                    e5_win_end_wus.append(0)
            elif len(vals['components'][comp]['windows'])==1:
                if comp == 'Z':
                    z_windows_wus.append(1)
                    z1_win_start_wus.append(vals['components'][comp]['windows'][0]['window_start'])
                    z1_win_end_wus.append(vals['components'][comp]['windows'][0]['window_end'])
                    z2_win_start_wus.append(0)
                    z2_win_end_wus.append(0)
                    z3_win_start_wus.append(0)
                    z3_win_end_wus.append(0)
                    z4_win_start_wus.append(0)
                    z4_win_end_wus.append(0)
                    z5_win_start_wus.append(0)
                    z5_win_end_wus.append(0)
                elif comp == 'N':
                    n_windows_wus.append(1)
                    n1_win_start_wus.append(vals['components'][comp]['windows'][0]['window_start'])
                    n1_win_end_wus.append(vals['components'][comp]['windows'][0]['window_end'])
                    n2_win_start_wus.append(0)
                    n2_win_end_wus.append(0)
                    n3_win_start_wus.append(0)
                    n3_win_end_wus.append(0)
                    n4_win_start_wus.append(0)
                    n4_win_end_wus.append(0)
                    n5_win_start_wus.append(0)
                    n5_win_end_wus.append(0)
                elif comp =='E':
                    e_windows_wus.append(1)
                    e1_win_start_wus.append(vals['components'][comp]['windows'][0]['window_start'])
                    e1_win_end_wus.append(vals['components'][comp]['windows'][0]['window_end'])
                    e2_win_start_wus.append(0)
                    e2_win_end_wus.append(0)
                    e3_win_start_wus.append(0)
                    e3_win_end_wus.append(0)
                    e4_win_start_wus.append(0)
                    e4_win_end_wus.append(0)
                    e5_win_start_wus.append(0)
                    e5_win_end_wus.append(0)
            elif len(vals['components'][comp]['windows'])==2:
                if comp == 'Z':
                    z_windows_wus.append(2)
                    z1_win_start_wus.append(vals['components'][comp]['windows'][0]['window_start'])
                    z1_win_end_wus.append(vals['components'][comp]['windows'][0]['window_end'])
                    z2_win_start_wus.append(vals['components'][comp]['windows'][1]['window_start'])
                    z2_win_end_wus.append(vals['components'][comp]['windows'][1]['window_end'])
                    z3_win_start_wus.append(0)
                    z3_win_end_wus.append(0)
                    z4_win_start_wus.append(0)
                    z4_win_end_wus.append(0)
                    z5_win_start_wus.append(0)
                    z5_win_end_wus.append(0)
                elif comp == 'N':
                    n_windows_wus.append(2)
                    n1_win_start_wus.append(vals['components'][comp]['windows'][0]['window_start'])
                    n1_win_end_wus.append(vals['components'][comp]['windows'][0]['window_end'])
                    n2_win_start_wus.append(vals['components'][comp]['windows'][1]['window_start'])
                    n2_win_end_wus.append(vals['components'][comp]['windows'][1]['window_end'])
                    n3_win_start_wus.append(0)
                    n3_win_end_wus.append(0)
                    n4_win_start_wus.append(0)
                    n4_win_end_wus.append(0)
                    n5_win_start_wus.append(0)
                    n5_win_end_wus.append(0)
                elif comp =='E':
                    e_windows_wus.append(2)
                    e1_win_start_wus.append(vals['components'][comp]['windows'][0]['window_start'])
                    e1_win_end_wus.append(vals['components'][comp]['windows'][0]['window_end'])
                    e2_win_start_wus.append(vals['components'][comp]['windows'][1]['window_start'])
                    e2_win_end_wus.append(vals['components'][comp]['windows'][1]['window_end'])
                    e3_win_start_wus.append(0)
                    e3_win_end_wus.append(0)
                    e4_win_start_wus.append(0)
                    e4_win_end_wus.append(0)
                    e5_win_start_wus.append(0)
                    e5_win_end_wus.append(0)
            elif len(vals['components'][comp]['windows'])==3:
                if comp == 'Z':
                    z_windows_wus.append(3)
                    z1_win_start_wus.append(vals['components'][comp]['windows'][0]['window_start'])
                    z1_win_end_wus.append(vals['components'][comp]['windows'][0]['window_end'])
                    z2_win_start_wus.append(vals['components'][comp]['windows'][1]['window_start'])
                    z2_win_end_wus.append(vals['components'][comp]['windows'][1]['window_end'])
                    z3_win_start_wus.append(vals['components'][comp]['windows'][2]['window_start'])
                    z3_win_end_wus.append(vals['components'][comp]['windows'][2]['window_end'])
                    z4_win_start_wus.append(0)
                    z4_win_end_wus.append(0)
                    z5_win_start_wus.append(0)
                    z5_win_end_wus.append(0)
                elif comp == 'N':
                    n_windows_wus.append(3)
                    n1_win_start_wus.append(vals['components'][comp]['windows'][0]['window_start'])
                    n1_win_end_wus.append(vals['components'][comp]['windows'][0]['window_end'])
                    n2_win_start_wus.append(vals['components'][comp]['windows'][1]['window_start'])
                    n2_win_end_wus.append(vals['components'][comp]['windows'][1]['window_end'])
                    n3_win_start_wus.append(vals['components'][comp]['windows'][2]['window_start'])
                    n3_win_end_wus.append(vals['components'][comp]['windows'][2]['window_end'])
                    n4_win_start_wus.append(0)
                    n4_win_end_wus.append(0)
                    n5_win_start_wus.append(0)
                    n5_win_end_wus.append(0)
                elif comp =='E':
                    e_windows_wus.append(3)
                    e1_win_start_wus.append(vals['components'][comp]['windows'][0]['window_start'])
                    e1_win_end_wus.append(vals['components'][comp]['windows'][0]['window_end'])
                    e2_win_start_wus.append(vals['components'][comp]['windows'][1]['window_start'])
                    e2_win_end_wus.append(vals['components'][comp]['windows'][1]['window_end'])
                    e3_win_start_wus.append(vals['components'][comp]['windows'][2]['window_start'])
                    e3_win_end_wus.append(vals['components'][comp]['windows'][2]['window_end'])
                    e4_win_start_wus.append(0)
                    e4_win_end_wus.append(0)
                    e5_win_start_wus.append(0)
                    e5_win_end_wus.append(0)
            elif len(vals['components'][comp]['windows'])==4:
                if comp == 'Z':
                    z_windows_wus.append(4)
                    z1_win_start_wus.append(vals['components'][comp]['windows'][0]['window_start'])
                    z1_win_end_wus.append(vals['components'][comp]['windows'][0]['window_end'])
                    z2_win_start_wus.append(vals['components'][comp]['windows'][1]['window_start'])
                    z2_win_end_wus.append(vals['components'][comp]['windows'][1]['window_end'])
                    z3_win_start_wus.append(vals['components'][comp]['windows'][2]['window_start'])
                    z3_win_end_wus.append(vals['components'][comp]['windows'][2]['window_end'])
                    z4_win_start_wus.append(vals['components'][comp]['windows'][3]['window_start'])
                    z4_win_end_wus.append(vals['components'][comp]['windows'][3]['window_end'])
                    z5_win_start_wus.append(0)
                    z5_win_end_wus.append(0)
                elif comp == 'N':
                    n_windows_wus.append(4)
                    n1_win_start_wus.append(vals['components'][comp]['windows'][0]['window_start'])
                    n1_win_end_wus.append(vals['components'][comp]['windows'][0]['window_end'])
                    n2_win_start_wus.append(vals['components'][comp]['windows'][1]['window_start'])
                    n2_win_end_wus.append(vals['components'][comp]['windows'][1]['window_end'])
                    n3_win_start_wus.append(vals['components'][comp]['windows'][2]['window_start'])
                    n3_win_end_wus.append(vals['components'][comp]['windows'][2]['window_end'])
                    n4_win_start_wus.append(vals['components'][comp]['windows'][3]['window_start'])
                    n4_win_end_wus.append(vals['components'][comp]['windows'][3]['window_end'])
                    n5_win_start_wus.append(0)
                    n5_win_end_wus.append(0)
                elif comp =='E':
                    e_windows_wus.append(4)
                    e1_win_start_wus.append(vals['components'][comp]['windows'][0]['window_start'])
                    e1_win_end_wus.append(vals['components'][comp]['windows'][0]['window_end'])
                    e2_win_start_wus.append(vals['components'][comp]['windows'][1]['window_start'])
                    e2_win_end_wus.append(vals['components'][comp]['windows'][1]['window_end'])
                    e3_win_start_wus.append(vals['components'][comp]['windows'][2]['window_start'])
                    e3_win_end_wus.append(vals['components'][comp]['windows'][2]['window_end'])
                    e4_win_start_wus.append(vals['components'][comp]['windows'][3]['window_start'])
                    e4_win_end_wus.append(vals['components'][comp]['windows'][3]['window_end'])
                    e5_win_start_wus.append(0)
                    e5_win_end_wus.append(0)
            elif len(vals['components'][comp]['windows'])==5:
                if comp == 'Z':
                    z_windows_wus.append(5)
                    z1_win_start_wus.append(vals['components'][comp]['windows'][0]['window_start'])
                    z1_win_end_wus.append(vals['components'][comp]['windows'][0]['window_end'])
                    z2_win_start_wus.append(vals['components'][comp]['windows'][1]['window_start'])
                    z2_win_end_wus.append(vals['components'][comp]['windows'][1]['window_end'])
                    z3_win_start_wus.append(vals['components'][comp]['windows'][2]['window_start'])
                    z3_win_end_wus.append(vals['components'][comp]['windows'][2]['window_end'])
                    z4_win_start_wus.append(vals['components'][comp]['windows'][3]['window_start'])
                    z4_win_end_wus.append(vals['components'][comp]['windows'][3]['window_end'])
                    z5_win_start_wus.append(vals['components'][comp]['windows'][4]['window_start'])
                    z5_win_end_wus.append(vals['components'][comp]['windows'][4]['window_end'])
                elif comp == 'N':
                    n_windows_wus.append(5)
                    n1_win_start_wus.append(vals['components'][comp]['windows'][0]['window_start'])
                    n1_win_end_wus.append(vals['components'][comp]['windows'][0]['window_end'])
                    n2_win_start_wus.append(vals['components'][comp]['windows'][1]['window_start'])
                    n2_win_end_wus.append(vals['components'][comp]['windows'][1]['window_end'])
                    n3_win_start_wus.append(vals['components'][comp]['windows'][2]['window_start'])
                    n3_win_end_wus.append(vals['components'][comp]['windows'][2]['window_end'])
                    n4_win_start_wus.append(vals['components'][comp]['windows'][3]['window_start'])
                    n4_win_end_wus.append(vals['components'][comp]['windows'][3]['window_end'])
                    n5_win_start_wus.append(vals['components'][comp]['windows'][4]['window_start'])
                    n5_win_end_wus.append(vals['components'][comp]['windows'][4]['window_end'])
                elif comp =='E':
                    e_windows_wus.append(5)
                    e1_win_start_wus.append(vals['components'][comp]['windows'][0]['window_start'])
                    e1_win_end_wus.append(vals['components'][comp]['windows'][0]['window_end'])
                    e2_win_start_wus.append(vals['components'][comp]['windows'][1]['window_start'])
                    e2_win_end_wus.append(vals['components'][comp]['windows'][1]['window_end'])
                    e3_win_start_wus.append(vals['components'][comp]['windows'][2]['window_start'])
                    e3_win_end_wus.append(vals['components'][comp]['windows'][2]['window_end'])
                    e4_win_start_wus.append(vals['components'][comp]['windows'][3]['window_start'])
                    e4_win_end_wus.append(vals['components'][comp]['windows'][3]['window_end'])
                    e5_win_start_wus.append(vals['components'][comp]['windows'][4]['window_start'])
                    e5_win_end_wus.append(vals['components'][comp]['windows'][4]['window_end'])

# %%
z_windows_csem = []
n_windows_csem = []
e_windows_csem = []

z1_win_start_csem = []
n1_win_start_csem = []
e1_win_start_csem = []
z1_win_end_csem = []
n1_win_end_csem = []
e1_win_end_csem = []


z2_win_start_csem = []
n2_win_start_csem = []
e2_win_start_csem = []
z2_win_end_csem = []
n2_win_end_csem = []
e2_win_end_csem = []


z3_win_start_csem = []
n3_win_start_csem = []
e3_win_start_csem = []
z3_win_end_csem = []
n3_win_end_csem = []
e3_win_end_csem = []


z4_win_start_csem = []
n4_win_start_csem = []
e4_win_start_csem = []
z4_win_end_csem = []
n4_win_end_csem = []
e4_win_end_csem = []

z5_win_start_csem = []
n5_win_start_csem = []
e5_win_start_csem = []
z5_win_end_csem = []
n5_win_end_csem = []
e5_win_end_csem = []



for eve in csem.events.list():
    ds_csem = csem.entities.get(
            entity_type="data_selection_configuration",
            entity_name="CSEM",
            )
    ds_csem = ds_csem.get_event_window_and_weight_set(csem.events.get(event_name=eve))
    for idx in ds_csem.receivers:
        vals = ds_csem.receivers[idx]
        for comp in ['Z','N','E']:
            if len(vals['components'][comp]['windows'])==0:
                if comp == 'Z':
                    z_windows_csem.append(0)
                    z1_win_start_csem.append(0)
                    z1_win_end_csem.append(0)
                    z2_win_start_csem.append(0)
                    z2_win_end_csem.append(0)
                    z3_win_start_csem.append(0)
                    z3_win_end_csem.append(0)
                    z4_win_start_csem.append(0)
                    z4_win_end_csem.append(0)
                    z5_win_start_csem.append(0)
                    z5_win_end_csem.append(0)
                elif comp == 'N':
                    n_windows_csem.append(0)
                    n1_win_start_csem.append(0)
                    n1_win_end_csem.append(0)
                    n2_win_start_csem.append(0)
                    n2_win_end_csem.append(0)
                    n3_win_start_csem.append(0)
                    n3_win_end_csem.append(0)
                    n4_win_start_csem.append(0)
                    n4_win_end_csem.append(0)
                    n5_win_start_csem.append(0)
                    n5_win_end_csem.append(0)
                elif comp =='E':
                    e_windows_csem.append(0)
                    e1_win_start_csem.append(0)
                    e1_win_end_csem.append(0)
                    e2_win_start_csem.append(0)
                    e2_win_end_csem.append(0)
                    e3_win_start_csem.append(0)
                    e3_win_end_csem.append(0)
                    e4_win_start_csem.append(0)
                    e4_win_end_csem.append(0)
                    e5_win_start_csem.append(0)
                    e5_win_end_csem.append(0)
            elif len(vals['components'][comp]['windows'])==1:
                if comp == 'Z':
                    z_windows_csem.append(1)
                    z1_win_start_csem.append(vals['components'][comp]['windows'][0]['window_start'])
                    z1_win_end_csem.append(vals['components'][comp]['windows'][0]['window_end'])
                    z2_win_start_csem.append(0)
                    z2_win_end_csem.append(0)
                    z3_win_start_csem.append(0)
                    z3_win_end_csem.append(0)
                    z4_win_start_csem.append(0)
                    z4_win_end_csem.append(0)
                    z5_win_start_csem.append(0)
                    z5_win_end_csem.append(0)
                elif comp == 'N':
                    n_windows_csem.append(1)
                    n1_win_start_csem.append(vals['components'][comp]['windows'][0]['window_start'])
                    n1_win_end_csem.append(vals['components'][comp]['windows'][0]['window_end'])
                    n2_win_start_csem.append(0)
                    n2_win_end_csem.append(0)
                    n3_win_start_csem.append(0)
                    n3_win_end_csem.append(0)
                    n4_win_start_csem.append(0)
                    n4_win_end_csem.append(0)
                    n5_win_start_csem.append(0)
                    n5_win_end_csem.append(0)
                elif comp =='E':
                    e_windows_csem.append(1)
                    e1_win_start_csem.append(vals['components'][comp]['windows'][0]['window_start'])
                    e1_win_end_csem.append(vals['components'][comp]['windows'][0]['window_end'])
                    e2_win_start_csem.append(0)
                    e2_win_end_csem.append(0)
                    e3_win_start_csem.append(0)
                    e3_win_end_csem.append(0)
                    e4_win_start_csem.append(0)
                    e4_win_end_csem.append(0)
                    e5_win_start_csem.append(0)
                    e5_win_end_csem.append(0)
            elif len(vals['components'][comp]['windows'])==2:
                if comp == 'Z':
                    z_windows_csem.append(2)
                    z1_win_start_csem.append(vals['components'][comp]['windows'][0]['window_start'])
                    z1_win_end_csem.append(vals['components'][comp]['windows'][0]['window_end'])
                    z2_win_start_csem.append(vals['components'][comp]['windows'][1]['window_start'])
                    z2_win_end_csem.append(vals['components'][comp]['windows'][1]['window_end'])
                    z3_win_start_csem.append(0)
                    z3_win_end_csem.append(0)
                    z4_win_start_csem.append(0)
                    z4_win_end_csem.append(0)
                    z5_win_start_csem.append(0)
                    z5_win_end_csem.append(0)
                elif comp == 'N':
                    n_windows_csem.append(2)
                    n1_win_start_csem.append(vals['components'][comp]['windows'][0]['window_start'])
                    n1_win_end_csem.append(vals['components'][comp]['windows'][0]['window_end'])
                    n2_win_start_csem.append(vals['components'][comp]['windows'][1]['window_start'])
                    n2_win_end_csem.append(vals['components'][comp]['windows'][1]['window_end'])
                    n3_win_start_csem.append(0)
                    n3_win_end_csem.append(0)
                    n4_win_start_csem.append(0)
                    n4_win_end_csem.append(0)
                    n5_win_start_csem.append(0)
                    n5_win_end_csem.append(0)
                elif comp =='E':
                    e_windows_csem.append(2)
                    e1_win_start_csem.append(vals['components'][comp]['windows'][0]['window_start'])
                    e1_win_end_csem.append(vals['components'][comp]['windows'][0]['window_end'])
                    e2_win_start_csem.append(vals['components'][comp]['windows'][1]['window_start'])
                    e2_win_end_csem.append(vals['components'][comp]['windows'][1]['window_end'])
                    e3_win_start_csem.append(0)
                    e3_win_end_csem.append(0)
                    e4_win_start_csem.append(0)
                    e4_win_end_csem.append(0)
                    e5_win_start_csem.append(0)
                    e5_win_end_csem.append(0)
            elif len(vals['components'][comp]['windows'])==3:
                if comp == 'Z':
                    z_windows_csem.append(3)
                    z1_win_start_csem.append(vals['components'][comp]['windows'][0]['window_start'])
                    z1_win_end_csem.append(vals['components'][comp]['windows'][0]['window_end'])
                    z2_win_start_csem.append(vals['components'][comp]['windows'][1]['window_start'])
                    z2_win_end_csem.append(vals['components'][comp]['windows'][1]['window_end'])
                    z3_win_start_csem.append(vals['components'][comp]['windows'][2]['window_start'])
                    z3_win_end_csem.append(vals['components'][comp]['windows'][2]['window_end'])
                    z4_win_start_csem.append(0)
                    z4_win_end_csem.append(0)
                    z5_win_start_csem.append(0)
                    z5_win_end_csem.append(0)
                elif comp == 'N':
                    n_windows_csem.append(3)
                    n1_win_start_csem.append(vals['components'][comp]['windows'][0]['window_start'])
                    n1_win_end_csem.append(vals['components'][comp]['windows'][0]['window_end'])
                    n2_win_start_csem.append(vals['components'][comp]['windows'][1]['window_start'])
                    n2_win_end_csem.append(vals['components'][comp]['windows'][1]['window_end'])
                    n3_win_start_csem.append(vals['components'][comp]['windows'][2]['window_start'])
                    n3_win_end_csem.append(vals['components'][comp]['windows'][2]['window_end'])
                    n4_win_start_csem.append(0)
                    n4_win_end_csem.append(0)
                    n5_win_start_csem.append(0)
                    n5_win_end_csem.append(0)
                elif comp =='E':
                    e_windows_csem.append(3)
                    e1_win_start_csem.append(vals['components'][comp]['windows'][0]['window_start'])
                    e1_win_end_csem.append(vals['components'][comp]['windows'][0]['window_end'])
                    e2_win_start_csem.append(vals['components'][comp]['windows'][1]['window_start'])
                    e2_win_end_csem.append(vals['components'][comp]['windows'][1]['window_end'])
                    e3_win_start_csem.append(vals['components'][comp]['windows'][2]['window_start'])
                    e3_win_end_csem.append(vals['components'][comp]['windows'][2]['window_end'])
                    e4_win_start_csem.append(0)
                    e4_win_end_csem.append(0)
                    e5_win_start_csem.append(0)
                    e5_win_end_csem.append(0)
            elif len(vals['components'][comp]['windows'])==4:
                if comp == 'Z':
                    z_windows_csem.append(4)
                    z1_win_start_csem.append(vals['components'][comp]['windows'][0]['window_start'])
                    z1_win_end_csem.append(vals['components'][comp]['windows'][0]['window_end'])
                    z2_win_start_csem.append(vals['components'][comp]['windows'][1]['window_start'])
                    z2_win_end_csem.append(vals['components'][comp]['windows'][1]['window_end'])
                    z3_win_start_csem.append(vals['components'][comp]['windows'][2]['window_start'])
                    z3_win_end_csem.append(vals['components'][comp]['windows'][2]['window_end'])
                    z4_win_start_csem.append(vals['components'][comp]['windows'][3]['window_start'])
                    z4_win_end_csem.append(vals['components'][comp]['windows'][3]['window_end'])
                    z5_win_start_csem.append(0)
                    z5_win_end_csem.append(0)
                elif comp == 'N':
                    n_windows_csem.append(4)
                    n1_win_start_csem.append(vals['components'][comp]['windows'][0]['window_start'])
                    n1_win_end_csem.append(vals['components'][comp]['windows'][0]['window_end'])
                    n2_win_start_csem.append(vals['components'][comp]['windows'][1]['window_start'])
                    n2_win_end_csem.append(vals['components'][comp]['windows'][1]['window_end'])
                    n3_win_start_csem.append(vals['components'][comp]['windows'][2]['window_start'])
                    n3_win_end_csem.append(vals['components'][comp]['windows'][2]['window_end'])
                    n4_win_start_csem.append(vals['components'][comp]['windows'][3]['window_start'])
                    n4_win_end_csem.append(vals['components'][comp]['windows'][3]['window_end'])
                    n5_win_start_csem.append(0)
                    n5_win_end_csem.append(0)
                elif comp =='E':
                    e_windows_csem.append(4)
                    e1_win_start_csem.append(vals['components'][comp]['windows'][0]['window_start'])
                    e1_win_end_csem.append(vals['components'][comp]['windows'][0]['window_end'])
                    e2_win_start_csem.append(vals['components'][comp]['windows'][1]['window_start'])
                    e2_win_end_csem.append(vals['components'][comp]['windows'][1]['window_end'])
                    e3_win_start_csem.append(vals['components'][comp]['windows'][2]['window_start'])
                    e3_win_end_csem.append(vals['components'][comp]['windows'][2]['window_end'])
                    e4_win_start_csem.append(vals['components'][comp]['windows'][3]['window_start'])
                    e4_win_end_csem.append(vals['components'][comp]['windows'][3]['window_end'])
                    e5_win_start_csem.append(0)
                    e5_win_end_csem.append(0)
            elif len(vals['components'][comp]['windows'])==5:
                if comp == 'Z':
                    z_windows_csem.append(5)
                    z1_win_start_csem.append(vals['components'][comp]['windows'][0]['window_start'])
                    z1_win_end_csem.append(vals['components'][comp]['windows'][0]['window_end'])
                    z2_win_start_csem.append(vals['components'][comp]['windows'][1]['window_start'])
                    z2_win_end_csem.append(vals['components'][comp]['windows'][1]['window_end'])
                    z3_win_start_csem.append(vals['components'][comp]['windows'][2]['window_start'])
                    z3_win_end_csem.append(vals['components'][comp]['windows'][2]['window_end'])
                    z4_win_start_csem.append(vals['components'][comp]['windows'][3]['window_start'])
                    z4_win_end_csem.append(vals['components'][comp]['windows'][3]['window_end'])
                    z5_win_start_csem.append(vals['components'][comp]['windows'][4]['window_start'])
                    z5_win_end_csem.append(vals['components'][comp]['windows'][4]['window_end'])
                elif comp == 'N':
                    n_windows_csem.append(5)
                    n1_win_start_csem.append(vals['components'][comp]['windows'][0]['window_start'])
                    n1_win_end_csem.append(vals['components'][comp]['windows'][0]['window_end'])
                    n2_win_start_csem.append(vals['components'][comp]['windows'][1]['window_start'])
                    n2_win_end_csem.append(vals['components'][comp]['windows'][1]['window_end'])
                    n3_win_start_csem.append(vals['components'][comp]['windows'][2]['window_start'])
                    n3_win_end_csem.append(vals['components'][comp]['windows'][2]['window_end'])
                    n4_win_start_csem.append(vals['components'][comp]['windows'][3]['window_start'])
                    n4_win_end_csem.append(vals['components'][comp]['windows'][3]['window_end'])
                    n5_win_start_csem.append(vals['components'][comp]['windows'][4]['window_start'])
                    n5_win_end_csem.append(vals['components'][comp]['windows'][4]['window_end'])
                elif comp =='E':
                    e_windows_csem.append(5)
                    e1_win_start_csem.append(vals['components'][comp]['windows'][0]['window_start'])
                    e1_win_end_csem.append(vals['components'][comp]['windows'][0]['window_end'])
                    e2_win_start_csem.append(vals['components'][comp]['windows'][1]['window_start'])
                    e2_win_end_csem.append(vals['components'][comp]['windows'][1]['window_end'])
                    e3_win_start_csem.append(vals['components'][comp]['windows'][2]['window_start'])
                    e3_win_end_csem.append(vals['components'][comp]['windows'][2]['window_end'])
                    e4_win_start_csem.append(vals['components'][comp]['windows'][3]['window_start'])
                    e4_win_end_csem.append(vals['components'][comp]['windows'][3]['window_end'])
                    e5_win_start_csem.append(vals['components'][comp]['windows'][4]['window_start'])
                    e5_win_end_csem.append(vals['components'][comp]['windows'][4]['window_end'])

# %%
n=0
eve_check = []

z_windows_sp = []
n_windows_sp = []
e_windows_sp = []

z1_windows_sp = []
n1_windows_sp = []
e1_windows_sp = []
z1_win_start_sp = []
n1_win_start_sp = []
e1_win_start_sp = []
z1_win_end_sp = []
n1_win_end_sp = []
e1_win_end_sp = []
z2_windows_sp = []
n2_windows_sp = []
e2_windows_sp = []
z2_win_start_sp = []
n2_win_start_sp = []
e2_win_start_sp = []
z2_win_end_sp = []
n2_win_end_sp = []
e2_win_end_sp = []
z3_windows_sp = []
n3_windows_sp = []
e3_windows_sp = []
z3_win_start_sp = []
n3_win_start_sp = []
e3_win_start_sp = []
z3_win_end_sp = []
n3_win_end_sp = []
e3_win_end_sp = []
z4_windows_sp = []
n4_windows_sp = []
e4_windows_sp = []
z4_win_start_sp = []
n4_win_start_sp = []
e4_win_start_sp = []
z4_win_end_sp = []
n4_win_end_sp = []
e4_win_end_sp = []

z5_win_start_sp = []
n5_win_start_sp = []
e5_win_start_sp = []
z5_win_end_sp = []
n5_win_end_sp = []
e5_win_end_sp = []

ds_sp = sp.entities.get(
            entity_type="data_selection_configuration",
            entity_name="spiral",
            )

for st in step:
    st = st.split('/')
    eve = st[0]
    if eve not in eve_check:
        ds = ds_sp.get_event_window_and_weight_set(sp.events.get(event_name=eve))
        eve_check.append(eve)
    else:
        pass
    rec = st[-1]
    try:
        vals = ds.receivers[rec]
    except:
        pass

    for comp in ['Z','N','E']:
        if len(vals['components'][comp]['windows'])==0:
            if comp == 'Z':
                z_windows_sp.append(0)
                z1_win_start_sp.append(0)
                z1_win_end_sp.append(0)
                z2_win_start_sp.append(0)
                z2_win_end_sp.append(0)
                z3_win_start_sp.append(0)
                z3_win_end_sp.append(0)
                z4_win_start_sp.append(0)
                z4_win_end_sp.append(0)
                z5_win_start_sp.append(0)
                z5_win_end_sp.append(0)
            elif comp == 'N':
                n_windows_sp.append(0)
                n1_win_start_sp.append(0)
                n1_win_end_sp.append(0)
                n2_win_start_sp.append(0)
                n2_win_end_sp.append(0)
                n3_win_start_sp.append(0)
                n3_win_end_sp.append(0)
                n4_win_start_sp.append(0)
                n4_win_end_sp.append(0)
                n5_win_start_sp.append(0)
                n5_win_end_sp.append(0)
            elif comp =='E':
                e_windows_sp.append(0)
                e1_win_start_sp.append(0)
                e1_win_end_sp.append(0)
                e2_win_start_sp.append(0)
                e2_win_end_sp.append(0)
                e3_win_start_sp.append(0)
                e3_win_end_sp.append(0)
                e4_win_start_sp.append(0)
                e4_win_end_sp.append(0)
                e5_win_start_sp.append(0)
                e5_win_end_sp.append(0)
        elif len(vals['components'][comp]['windows'])==1:
            if comp == 'Z':
                z_windows_sp.append(1)
                z1_win_start_sp.append(vals['components'][comp]['windows'][0]['window_start'])
                z1_win_end_sp.append(vals['components'][comp]['windows'][0]['window_end'])
                z2_win_start_sp.append(0)
                z2_win_end_sp.append(0)
                z3_win_start_sp.append(0)
                z3_win_end_sp.append(0)
                z4_win_start_sp.append(0)
                z4_win_end_sp.append(0)
                z5_win_start_sp.append(0)
                z5_win_end_sp.append(0)
            elif comp == 'N':
                n_windows_sp.append(1)
                n1_win_start_sp.append(vals['components'][comp]['windows'][0]['window_start'])
                n1_win_end_sp.append(vals['components'][comp]['windows'][0]['window_end'])
                n2_win_start_sp.append(0)
                n2_win_end_sp.append(0)
                n3_win_start_sp.append(0)
                n3_win_end_sp.append(0)
                n4_win_start_sp.append(0)
                n4_win_end_sp.append(0)
                n5_win_start_sp.append(0)
                n5_win_end_sp.append(0)
            elif comp =='E':
                e_windows_sp.append(1)
                e1_win_start_sp.append(vals['components'][comp]['windows'][0]['window_start'])
                e1_win_end_sp.append(vals['components'][comp]['windows'][0]['window_end'])
                e2_win_start_sp.append(0)
                e2_win_end_sp.append(0)
                e3_win_start_sp.append(0)
                e3_win_end_sp.append(0)
                e4_win_start_sp.append(0)
                e4_win_end_sp.append(0)
                e5_win_start_sp.append(0)
                e5_win_end_sp.append(0)
        elif len(vals['components'][comp]['windows'])==2:
            if comp == 'Z':
                z_windows_sp.append(2)
                z1_win_start_sp.append(vals['components'][comp]['windows'][0]['window_start'])
                z1_win_end_sp.append(vals['components'][comp]['windows'][0]['window_end'])
                z2_win_start_sp.append(vals['components'][comp]['windows'][1]['window_start'])
                z2_win_end_sp.append(vals['components'][comp]['windows'][1]['window_end'])
                z3_win_start_sp.append(0)
                z3_win_end_sp.append(0)
                z4_win_start_sp.append(0)
                z4_win_end_sp.append(0)
                z5_win_start_sp.append(0)
                z5_win_end_sp.append(0)
            elif comp == 'N':
                n_windows_sp.append(2)
                n1_win_start_sp.append(vals['components'][comp]['windows'][0]['window_start'])
                n1_win_end_sp.append(vals['components'][comp]['windows'][0]['window_end'])
                n2_win_start_sp.append(vals['components'][comp]['windows'][1]['window_start'])
                n2_win_end_sp.append(vals['components'][comp]['windows'][1]['window_end'])
                n3_win_start_sp.append(0)
                n3_win_end_sp.append(0)
                n4_win_start_sp.append(0)
                n4_win_end_sp.append(0)
                n5_win_start_sp.append(0)
                n5_win_end_sp.append(0)
            elif comp =='E':
                e_windows_sp.append(2)
                e1_win_start_sp.append(vals['components'][comp]['windows'][0]['window_start'])
                e1_win_end_sp.append(vals['components'][comp]['windows'][0]['window_end'])
                e2_win_start_sp.append(vals['components'][comp]['windows'][1]['window_start'])
                e2_win_end_sp.append(vals['components'][comp]['windows'][1]['window_end'])
                e3_win_start_sp.append(0)
                e3_win_end_sp.append(0)
                e4_win_start_sp.append(0)
                e4_win_end_sp.append(0)
                e5_win_start_sp.append(0)
                e5_win_end_sp.append(0)
        elif len(vals['components'][comp]['windows'])==3:
            if comp == 'Z':
                z_windows_sp.append(3)
                z1_win_start_sp.append(vals['components'][comp]['windows'][0]['window_start'])
                z1_win_end_sp.append(vals['components'][comp]['windows'][0]['window_end'])
                z2_win_start_sp.append(vals['components'][comp]['windows'][1]['window_start'])
                z2_win_end_sp.append(vals['components'][comp]['windows'][1]['window_end'])
                z3_win_start_sp.append(vals['components'][comp]['windows'][2]['window_start'])
                z3_win_end_sp.append(vals['components'][comp]['windows'][2]['window_end'])
                z4_win_start_sp.append(0)
                z4_win_end_sp.append(0)
                z5_win_start_sp.append(0)
                z5_win_end_sp.append(0)
            elif comp == 'N':
                n_windows_sp.append(3)
                n1_win_start_sp.append(vals['components'][comp]['windows'][0]['window_start'])
                n1_win_end_sp.append(vals['components'][comp]['windows'][0]['window_end'])
                n2_win_start_sp.append(vals['components'][comp]['windows'][1]['window_start'])
                n2_win_end_sp.append(vals['components'][comp]['windows'][1]['window_end'])
                n3_win_start_sp.append(vals['components'][comp]['windows'][2]['window_start'])
                n3_win_end_sp.append(vals['components'][comp]['windows'][2]['window_end'])
                n4_win_start_sp.append(0)
                n4_win_end_sp.append(0)
                n5_win_start_sp.append(0)
                n5_win_end_sp.append(0)
            elif comp =='E':
                e_windows_sp.append(3)
                e1_win_start_sp.append(vals['components'][comp]['windows'][0]['window_start'])
                e1_win_end_sp.append(vals['components'][comp]['windows'][0]['window_end'])
                e2_win_start_sp.append(vals['components'][comp]['windows'][1]['window_start'])
                e2_win_end_sp.append(vals['components'][comp]['windows'][1]['window_end'])
                e3_win_start_sp.append(vals['components'][comp]['windows'][2]['window_start'])
                e3_win_end_sp.append(vals['components'][comp]['windows'][2]['window_end'])
                e4_win_start_sp.append(0)
                e4_win_end_sp.append(0)
                e5_win_start_sp.append(0)
                e5_win_end_sp.append(0)
        elif len(vals['components'][comp]['windows'])==4:
            if comp == 'Z':
                z_windows_sp.append(4)
                z1_win_start_sp.append(vals['components'][comp]['windows'][0]['window_start'])
                z1_win_end_sp.append(vals['components'][comp]['windows'][0]['window_end'])
                z2_win_start_sp.append(vals['components'][comp]['windows'][1]['window_start'])
                z2_win_end_sp.append(vals['components'][comp]['windows'][1]['window_end'])
                z3_win_start_sp.append(vals['components'][comp]['windows'][2]['window_start'])
                z3_win_end_sp.append(vals['components'][comp]['windows'][2]['window_end'])
                z4_win_start_sp.append(vals['components'][comp]['windows'][3]['window_start'])
                z4_win_end_sp.append(vals['components'][comp]['windows'][3]['window_end'])
                z5_win_start_sp.append(0)
                z5_win_end_sp.append(0)
            elif comp == 'N':
                n_windows_sp.append(4)
                n1_win_start_sp.append(vals['components'][comp]['windows'][0]['window_start'])
                n1_win_end_sp.append(vals['components'][comp]['windows'][0]['window_end'])
                n2_win_start_sp.append(vals['components'][comp]['windows'][1]['window_start'])
                n2_win_end_sp.append(vals['components'][comp]['windows'][1]['window_end'])
                n3_win_start_sp.append(vals['components'][comp]['windows'][2]['window_start'])
                n3_win_end_sp.append(vals['components'][comp]['windows'][2]['window_end'])
                n4_win_start_sp.append(vals['components'][comp]['windows'][3]['window_start'])
                n4_win_end_sp.append(vals['components'][comp]['windows'][3]['window_end'])
                n5_win_start_sp.append(0)
                n5_win_end_sp.append(0)
            elif comp =='E':
                e_windows_sp.append(4)
                e1_win_start_sp.append(vals['components'][comp]['windows'][0]['window_start'])
                e1_win_end_sp.append(vals['components'][comp]['windows'][0]['window_end'])
                e2_win_start_sp.append(vals['components'][comp]['windows'][1]['window_start'])
                e2_win_end_sp.append(vals['components'][comp]['windows'][1]['window_end'])
                e3_win_start_sp.append(vals['components'][comp]['windows'][2]['window_start'])
                e3_win_end_sp.append(vals['components'][comp]['windows'][2]['window_end'])
                e4_win_start_sp.append(vals['components'][comp]['windows'][3]['window_start'])
                e4_win_end_sp.append(vals['components'][comp]['windows'][3]['window_end'])
                e5_win_start_sp.append(0)
                e5_win_end_sp.append(0)
        elif len(vals['components'][comp]['windows'])==5:
            if comp == 'Z':
                z_windows_sp.append(5)
                z1_win_start_sp.append(vals['components'][comp]['windows'][0]['window_start'])
                z1_win_end_sp.append(vals['components'][comp]['windows'][0]['window_end'])
                z2_win_start_sp.append(vals['components'][comp]['windows'][1]['window_start'])
                z2_win_end_sp.append(vals['components'][comp]['windows'][1]['window_end'])
                z3_win_start_sp.append(vals['components'][comp]['windows'][2]['window_start'])
                z3_win_end_sp.append(vals['components'][comp]['windows'][2]['window_end'])
                z4_win_start_sp.append(vals['components'][comp]['windows'][3]['window_start'])
                z4_win_end_sp.append(vals['components'][comp]['windows'][3]['window_end'])
                z5_win_start_sp.append(vals['components'][comp]['windows'][4]['window_start'])
                z5_win_end_sp.append(vals['components'][comp]['windows'][4]['window_end'])
            elif comp == 'N':
                n_windows_sp.append(5)
                n1_win_start_sp.append(vals['components'][comp]['windows'][0]['window_start'])
                n1_win_end_sp.append(vals['components'][comp]['windows'][0]['window_end'])
                n2_win_start_sp.append(vals['components'][comp]['windows'][1]['window_start'])
                n2_win_end_sp.append(vals['components'][comp]['windows'][1]['window_end'])
                n3_win_start_sp.append(vals['components'][comp]['windows'][2]['window_start'])
                n3_win_end_sp.append(vals['components'][comp]['windows'][2]['window_end'])
                n4_win_start_sp.append(vals['components'][comp]['windows'][3]['window_start'])
                n4_win_end_sp.append(vals['components'][comp]['windows'][3]['window_end'])
                n5_win_start_sp.append(vals['components'][comp]['windows'][4]['window_start'])
                n5_win_end_sp.append(vals['components'][comp]['windows'][4]['window_end'])
            elif comp =='E':
                e_windows_sp.append(5)
                e1_win_start_sp.append(vals['components'][comp]['windows'][0]['window_start'])
                e1_win_end_sp.append(vals['components'][comp]['windows'][0]['window_end'])
                e2_win_start_sp.append(vals['components'][comp]['windows'][1]['window_start'])
                e2_win_end_sp.append(vals['components'][comp]['windows'][1]['window_end'])
                e3_win_start_sp.append(vals['components'][comp]['windows'][2]['window_start'])
                e3_win_end_sp.append(vals['components'][comp]['windows'][2]['window_end'])
                e4_win_start_sp.append(vals['components'][comp]['windows'][3]['window_start'])
                e4_win_end_sp.append(vals['components'][comp]['windows'][3]['window_end'])
                e5_win_start_sp.append(vals['components'][comp]['windows'][4]['window_start'])
                e5_win_end_sp.append(vals['components'][comp]['windows'][4]['window_end'])

print('Number of Exceptions: '+ str(n))
# Out:
# Number of Exceptions: 0

# %%
print(len(z_windows_csem))
# Out:
# 34303

# %%
window_info_cw = pd.DataFrame(np.column_stack([ 
                                               z_windows_sp, z_windows_wus,z_windows_csem,
                                                z1_win_start_sp, z1_win_end_sp,z2_win_start_sp, z2_win_end_sp,
                                                z3_win_start_sp, z3_win_end_sp,z4_win_start_sp, z4_win_end_sp,
                                                z5_win_start_sp, z5_win_end_sp,
                                                z1_win_start_wus, z1_win_end_wus,z2_win_start_wus, z2_win_end_wus,
                                                z3_win_start_wus, z3_win_end_wus,z4_win_start_wus, z4_win_end_wus,
                                                z5_win_start_wus, z5_win_end_wus,
                                                z1_win_start_csem, z1_win_end_csem,z2_win_start_csem, z2_win_end_csem,
                                                z3_win_start_csem, z3_win_end_csem,z4_win_start_csem, z4_win_end_csem,
                                                z5_win_start_csem, z5_win_end_csem,
                                              n_windows_sp, n_windows_wus,n_windows_csem,
                                                n1_win_start_sp, n1_win_end_sp,n2_win_start_sp, n2_win_end_sp,
                                                n3_win_start_sp, n3_win_end_sp,n4_win_start_sp, n4_win_end_sp,
                                                n5_win_start_sp, n5_win_end_sp,
                                                n1_win_start_wus, n1_win_end_wus,n2_win_start_wus, n2_win_end_wus,
                                                n3_win_start_wus, n3_win_end_wus,n4_win_start_wus, n4_win_end_wus,
                                                n5_win_start_wus, n5_win_end_wus,
                                                n1_win_start_csem, n1_win_end_csem,n2_win_start_csem, n2_win_end_csem,
                                                n3_win_start_csem, n3_win_end_csem,n4_win_start_csem, n4_win_end_csem,
                                                n5_win_start_csem, n5_win_end_csem,
                                              e_windows_sp, e_windows_wus,e_windows_csem,
                                                e1_win_start_sp, e1_win_end_sp,e2_win_start_sp, e2_win_end_sp,
                                                e3_win_start_sp, e3_win_end_sp,e4_win_start_sp, e4_win_end_sp,
                                                e5_win_start_sp, e5_win_end_sp,
                                                e1_win_start_wus, e1_win_end_wus,e2_win_start_wus, e2_win_end_wus,
                                                e3_win_start_wus, e3_win_end_wus,e4_win_start_wus, e4_win_end_wus,
                                                e5_win_start_wus, e5_win_end_wus,
                                                e1_win_start_csem, e1_win_end_csem,e2_win_start_csem, e2_win_end_csem,
                                                e3_win_start_csem, e3_win_end_csem,e4_win_start_csem, e4_win_end_csem,
                                                e5_win_start_csem, e5_win_end_csem]), 
                              index = step,
                               columns=[ 
                                        'Z_SP', 'Z_WUS', 'Z_CSEM', 
                                        'Z1_Start_SP', 'Z1_End_SP', 'Z2_Start_SP', 'Z2_End_SP',
                                        'Z3_Start_SP', 'Z3_End_SP', 'Z4_Start_SP', 'Z4_End_SP',
                                        'Z5_Start_SP', 'Z5_End_SP',
                                        'Z1_Start_WUS', 'Z1_End_WUS', 'Z2_Start_WUS', 'Z2_End_WUS',
                                        'Z3_Start_WUS', 'Z3_End_WUS', 'Z4_Start_WUS', 'Z4_End_WUS',
                                        'Z5_Start_WUS', 'Z5_End_WUS',
                                        'Z1_Start_CSEM', 'Z1_End_CSEM', 'Z2_Start_CSEM', 'Z2_End_CSEM',
                                        'Z3_Start_CSEM', 'Z3_End_CSEM', 'Z4_Start_CSEM', 'Z4_End_CSEM',
                                        'Z5_Start_CSEM', 'Z5_End_CSEM',
                                        'N_SP', 'N_WUS', 'N_CSEM', 
                                        'N1_Start_SP', 'N1_End_SP', 'N2_Start_SP', 'N2_End_SP',
                                        'N3_Start_SP', 'N3_End_SP', 'N4_Start_SP', 'N4_End_SP',
                                        'N5_Start_SP', 'N5_End_SP',
                                        'N1_Start_WUS', 'N1_End_WUS', 'N2_Start_WUS', 'N2_End_WUS',
                                        'N3_Start_WUS', 'N3_End_WUS', 'N4_Start_WUS', 'N4_End_WUS',
                                        'N5_Start_WUS', 'N5_End_WUS',
                                        'N1_Start_CSEM', 'N1_End_CSEM', 'N2_Start_CSEM', 'N2_End_CSEM',
                                        'N3_Start_CSEM', 'N3_End_CSEM', 'N4_Start_CSEM', 'N4_End_CSEM',
                                        'N5_Start_CSEM', 'N5_End_CSEM',
                                        'E_SP', 'E_WUS', 'E_CSEM', 
                                        'E1_Start_SP', 'E1_End_SP', 'E2_Start_SP', 'E2_End_SP',
                                        'E3_Start_SP', 'E3_End_SP', 'E4_Start_SP', 'E4_End_SP',
                                        'E5_Start_SP', 'E5_End_SP',
                                        'E1_Start_WUS', 'E1_End_WUS', 'E2_Start_WUS', 'E2_End_WUS',
                                        'E3_Start_WUS', 'E3_End_WUS', 'E4_Start_WUS', 'E4_End_WUS',
                                        'E5_Start_WUS', 'E5_End_WUS',
                                        'E1_Start_CSEM', 'E1_End_CSEM', 'E2_Start_CSEM', 'E2_End_CSEM',
                                        'E3_Start_CSEM', 'E3_End_CSEM', 'E4_Start_CSEM', 'E4_End_CSEM',
                                        'E5_Start_CSEM', 'E5_End_CSEM'
                               ])

window_info_cw
# Out:
#                                                     Z_SP  Z_WUS  Z_CSEM  \
# event_BAJA_CALIFORNIA_MEXICO_Mag_4.85_2010-04-1...   0.0    0.0     0.0
# event_BAJA_CALIFORNIA_MEXICO_Mag_4.85_2010-04-1...   0.0    0.0     0.0
# event_BAJA_CALIFORNIA_MEXICO_Mag_4.85_2010-04-1...   1.0    1.0     1.0
# event_BAJA_CALIFORNIA_MEXICO_Mag_4.85_2010-04-1...   0.0    0.0     0.0
# event_BAJA_CALIFORNIA_MEXICO_Mag_4.85_2010-04-1...   0.0    0.0     0.0
# ...                                                  ...    ...     ...
# event_W._ARIZONA-SONORA_BORDER_REGION_Mag_5.75_...   0.0    0.0     0.0
# event_W._ARIZONA-SONORA_BORDER_REGION_Mag_5.75_...   0.0    0.0     0.0
# event_W._ARIZONA-SONORA_BORDER_REGION_Mag_5.75_...   1.0    1.0     1.0
# event_W._ARIZONA-SONORA_BORDER_REGION_Mag_5.75_...   0.0    0.0     0.0
# event_W._ARIZONA-SONORA_BORDER_REGION_Mag_5.75_...   0.0    0.0     0.0
#
#                                                     Z1_Start_SP   Z1_End_SP  \
# ...

# %%
window_info_cw.to_csv('Starting_Model_wins.csv')
